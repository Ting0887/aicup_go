# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, ReLU, Flatten, Dense, Softmax, MaxPooling2D,BatchNormalization, ELU, Dropout
from tensorflow.keras.optimizers import Adam
import numpy as np
from sklearn.model_selection import train_test_split
from keras import regularizers

# %%
tf.__version__
# Out:
# '2.13.0'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Data Pre-Processing
#
# Open **dan_train.csv** file and split the games into a list.
# Every row of csv: `DL0000000001,B,B[pd],W[dp],B[pp],W[dc],B[de],...`.
#
# Columns are:
#
#     1. DL0000000001: Game ID
#     2. B: Player's color
#     3-... : Moves
#
# We cropped only the moves to game list as:

# %%
df = open('/content/drive/Shareddrives/AICUP圍棋Dataset/dan_train.csv').read().splitlines()
games = [i.split(',',2)[-1] for i in df]

# %% [markdown]
# Create a dictionary to convert the coordinates from characters to numbers

# %%
chars = 'abcdefghijklmnopqrs'
coordinates = {k:v for v,k in enumerate(chars)}
chartonumbers = {k:v for k,v in enumerate(chars)}
coordinates
# Out:
# {'a': 0,
#  'b': 1,
#  'c': 2,
#  'd': 3,
#  'e': 4,
#  'f': 5,
#  'g': 6,
#  'h': 7,
#  'i': 8,
#  'j': 9,
#  'k': 10,
#  'l': 11,
#  'm': 12,
#  'n': 13,
#  'o': 14,
#  'p': 15,
#  'q': 16,
#  'r': 17,
#  's': 18}

# %% [markdown]
# We decided to build a DCNN model in this tutorial. We create data samples by using every move in every game, meaning that the target is to predict the next move by feeding the previous state of the table in every game for every move. Therefore, we can collect much more data samples from games.
#
# For the simplicity, we used 4 dimensional feature map to represent the data as below:
#  1. Positions of black stones: mark them as 1 and the rest of the table as 0
#  2. Positions of white stones: mark them as 1 and the rest of the table as 0
#  3. Empty areas of the table: mark the empty areas as 1 and occupied areas as 0
#  4. The last move in the table: mark the position of the last move as 1 and the rest as 0
#
# Target value is a number between 0-361(19\*19). Later this will be one-hot encoded.

# %%
def prepare_input(moves):
    x = np.zeros((19, 19, 7))
    for move in moves:
        color = move[0]
        column = coordinates[move[2]]
        row = coordinates[move[3]]
        if color == 'B':
            x[row,column,0] = 1
            x[row,column,2] = 1
        if color == 'W':
            x[row,column,1] = 1
            x[row,column,2] = 1
    if moves:
        last_move_column = coordinates[moves[-1][2]]
        last_move_row = coordinates[moves[-1][3]]
        x[row,column,3] = 1
    x[:,:,2] = np.where(x[:,:,2] == 0, 1, 0)
    return x

def prepare_label(move):
    column = coordinates[move[2]]
    row = coordinates[move[3]]
    return column*19+row

# %%
# Check how many samples can be obtained
n_games = 0
n_moves = 0
for game in games:
    n_games += 1
    moves_list = game.split(',')
    for move in moves_list:
        n_moves += 1
print(f"Total Games: {n_games}, Total Moves: {n_moves}")
# Out:
# Total Games: 100160, Total Moves: 22853380

# %% [markdown]
# The code below is run for baseline model only by using only the first 500 games from the dataset. You might need to create a data generator to use complete dataset. Otherwise your RAM might not enough to store all (If you run the code on free version of Google Colab, it will crash above 500 game samples).

# %%
import random
x = []
y = []
games = random.sample(games, 500)
for game in games:
    moves_list = game.split(',')
    for count, move in enumerate(moves_list):
        x.append(prepare_input(moves_list[:count]))
        y.append(prepare_label(moves_list[count]))
x = np.array(x)
y = np.array(y)

# %%
x.shape
# Out:
# (112359, 19, 19, 7)

# %%
y.shape
# Out:
# (112359,)

# %%
y_one_hot = tf.one_hot(y, depth=19*19)

# %% [markdown]
# Dataset splitting: 90% Training, 10% validation

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y_one_hot.numpy(), test_size=0.10)

# %% [markdown]
# # Training
#
# ### Simple DCNN Model:

# %%
def create_model():
    inputs = Input(shape=(19, 19, 7))
    outputs = Conv2D(kernel_size=12, filters=3, padding='same', activation='relu', kernel_regularizer= regularizers.l2(0.0001))(inputs)
    outputs = BatchNormalization()(outputs)
    outputs = Conv2D(kernel_size=12, filters=3, padding='same', activation='relu', kernel_regularizer= regularizers.l2(0.001))(outputs)
    outputs = BatchNormalization()(outputs)
    outputs = Conv2D(kernel_size=12, filters=3, padding='same', activation='relu', kernel_regularizer= regularizers.l2(0.0001))(outputs)
    outputs = BatchNormalization()(outputs)
    outputs = Conv2D(kernel_size=12, filters=3, padding='same', activation='relu', kernel_regularizer= regularizers.l2(0.0001))(outputs)
    outputs = BatchNormalization()(outputs)
    outputs = Conv2D(kernel_size=12, filters=3, padding='same', activation='relu', kernel_regularizer= regularizers.l2(0.0001))(outputs)
    outputs = BatchNormalization()(outputs)
    outputs = Conv2D(kernel_size=12, filters=1, padding='same', activation='relu',kernel_regularizer= regularizers.l2(0.0001))(outputs)
    outputs = BatchNormalization()(outputs)

    outputs = Flatten()(outputs)
    outputs = Softmax()(outputs)
    outputs = Dropout(0.05)(outputs)
    model = Model(inputs, outputs)

    opt = Adam(learning_rate=0.001)
    model.compile(optimizer=opt,
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# %%
model = create_model()
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 19, 19, 7)]       0
#
#  conv2d (Conv2D)             (None, 19, 19, 3)         3027
#
#  batch_normalization (Batch  (None, 19, 19, 3)         12
#  Normalization)
#
#  conv2d_1 (Conv2D)           (None, 19, 19, 3)         1299
#
#  batch_normalization_1 (Bat  (None, 19, 19, 3)         12
#  chNormalization)
#
#  conv2d_2 (Conv2D)           (None, 19, 19, 3)         1299
#
#  batch_normalization_2 (Bat  (None, 19, 19, 3)         12
#  chNormalization)
#
#  conv2d_3 (Conv2D)           (None, 19, 19, 3)         1299
#
#  batch_normalization_3 (Bat  (None, 19, 19, 3)         12
#  chNormalization)
#
#  conv2d_4 (Conv2D)           (None, 19, 19, 3)         1299
#
#  batch_normalization_4 (Bat  (None, 19, 19, 3)         12
#  chNormalization)
#
#  conv2d_5 (Conv2D)           (None, 19, 19, 1)         433
#
#  batch_normalization_5 (Bat  (None, 19, 19, 1)         4
#  chNormalization)
#
#  flatten (Flatten)           (None, 361)               0
#
#  softmax (Softmax)           (None, 361)               0
#
#  dropout (Dropout)           (None, 361)               0
#
# =================================================================
# Total params: 8720 (34.06 KB)
# Trainable params: 8688 (33.94 KB)
# Non-trainable params: 32 (128.00 Byte)
# _________________________________________________________________

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    "/content/drive/Shareddrives/AICUP圍棋Dataset/save_Dan_bestModel/best_model.h5",
    monitor = "val_loss",
    verbose = 0,
    save_best_only = True,
    save_weights_only = True,
    save_freq="epoch",
    options=None,
    initial_value_threshold=None,
)

# %%
history = model.fit(
    x = x_train,
    y = y_train,
    batch_size = 128,
    epochs = 80,
    callbacks=[model_checkpoint_callback],
    validation_data=(x_val, y_val),
)
# Out:
# Epoch 1/80
# 791/791 [==============================] - 22s 10ms/step - loss: 5.7284 - accuracy: 0.0231 - val_loss: 4.8773 - val_accuracy: 0.0408
# Epoch 2/80
# 791/791 [==============================] - 6s 8ms/step - loss: 5.1197 - accuracy: 0.0553 - val_loss: 4.6623 - val_accuracy: 0.0571
# Epoch 3/80
# 791/791 [==============================] - 7s 9ms/step - loss: 5.0699 - accuracy: 0.0667 - val_loss: 4.5425 - val_accuracy: 0.0704
# Epoch 4/80
# 791/791 [==============================] - 6s 8ms/step - loss: 5.0468 - accuracy: 0.0723 - val_loss: 4.5108 - val_accuracy: 0.0770
# Epoch 5/80
# 791/791 [==============================] - 7s 9ms/step - loss: 5.0002 - accuracy: 0.0758 - val_loss: 4.5720 - val_accuracy: 0.0748
# Epoch 6/80
# 791/791 [==============================] - 6s 8ms/step - loss: 5.0049 - accuracy: 0.0781 - val_loss: 4.6058 - val_accuracy: 0.0698
# Epoch 7/80
# 791/791 [==============================] - 7s 9ms/step - loss: 4.9813 - accuracy: 0.0812 - val_loss: 4.5185 - val_accuracy: 0.0819
# Epoch 8/80
# 791/791 [==============================] - 7s 8ms/step - loss: 4.9894 - accuracy: 0.0835 - val_loss: 4.4847 - val_accuracy: 0.0803
# Epoch 9/80
# 791/791 [==============================] - 8s 10ms/step - loss: 4.9757 - accuracy: 0.0864 - val_loss: 4.4696 - val_accuracy: 0.0869
# Epoch 10/80
# 791/791 [==============================] - 6s 8ms/step - loss: 4.9394 - accuracy: 0.0887 - val_loss: 4.4391 - val_accuracy: 0.0885
# Epoch 11/80
# 791/791 [==============================] - 7s 9ms/step - loss: 4.9353 - accuracy: 0.0908 - val_loss: 4.4537 - val_accuracy: 0.0910
# Epoch 12/80
# 791/791 [==============================] - 7s 9ms/step - loss: 4.9209 - accuracy: 0.0920 - val_loss: 4.5364 - val_accuracy: 0.0826
# Epoch 13/80
# 791/791 [==============================] - 7s 9ms/step - loss: 4.9297 - accuracy: 0.0945 - val_loss: 4.4430 - val_accuracy: 0.0888
# Epoch 14/80
# 791/791 [==============================] - 7s 8ms/step - loss: 4.8998 - accuracy: 0.0953 - val_loss: 4.4618 - val_accuracy: 0.0904
# Epoch 15/80
# 791/791 [==============================] - 7s 8ms/step - loss: 4.9018 - accuracy: 0.0965 - val_loss: 4.4491 - val_accuracy: 0.0875
# Epoch 16/80
# 791/791 [==============================] - 7s 9ms/step - loss: 4.8942 - accuracy: 0.0983 - val_loss: 4.5354 - val_accuracy: 0.0797
# Epoch 17/80
# 791/791 [==============================] - 7s 8ms/step - loss: 4.8819 - accuracy: 0.0990 - val_loss: 4.4807 - val_accuracy: 0.0856
# Epoch 18/80
# 791/791 [==============================] - 8s 10ms/step - loss: 4.8839 - accuracy: 0.1002 - val_loss: 4.3908 - val_accuracy: 0.0987
# Epoch 19/80
# 791/791 [==============================] - 6s 8ms/step - loss: 4.8808 - accuracy: 0.1018 - val_loss: 4.4118 - val_accuracy: 0.0940
# Epoch 20/80
# 791/791 [==============================] - 7s 9ms/step - loss: 4.8634 - accuracy: 0.1014 - val_loss: 4.3943 - val_accuracy: 0.0942
# Epoch 21/80
# 791/791 [==============================] - 7s 8ms/step - loss: 4.8693 - accuracy: 0.1031 - val_loss: 4.3674 - val_accuracy: 0.0975
# Epoch 22/80
# 791/791 [==============================] - 7s 9ms/step - loss: 4.8610 - accuracy: 0.1045 - val_loss: 4.4172 - val_accuracy: 0.0967
# Epoch 23/80
# 791/791 [==============================] - 6s 8ms/step - loss: 4.8619 - accuracy: 0.1053 - val_loss: 4.4154 - val_accuracy: 0.0906
# Epoch 24/80
# 791/791 [==============================] - 7s 9ms/step - loss: 4.8732 - accuracy: 0.1051 - val_loss: 4.3906 - val_accuracy: 0.1006
# Epoch 25/80
# 791/791 [==============================] - 6s 8ms/step - loss: 4.8421 - accuracy: 0.1072 - val_loss: 4.4132 - val_accuracy: 0.0951
# Epoch 26/80
# 791/791 [==============================] - 7s 9ms/step - loss: 4.8574 - accuracy: 0.1077 - val_loss: 4.3689 - val_accuracy: 0.1035
# Epoch 27/80
# 791/791 [==============================] - 6s 8ms/step - loss: 4.8457 - accuracy: 0.1098 - val_loss: 4.3983 - val_accuracy: 0.1008
# Epoch 28/80
# 791/791 [==============================] - 8s 10ms/step - loss: 4.8375 - accuracy: 0.1107 - val_loss: 4.3661 - val_accuracy: 0.1084
# Epoch 29/80
# 791/791 [==============================] - 7s 9ms/step - loss: 4.8278 - accuracy: 0.1119 - val_loss: 4.3494 - val_accuracy: 0.1072
# Epoch 30/80
# 791/791 [==============================] - 7s 9ms/step - loss: 4.8343 - accuracy: 0.1123 - val_loss: 4.3422 - val_accuracy: 0.1110
# Epoch 31/80
# 791/791 [==============================] - 7s 8ms/step - loss: 4.8365 - accuracy: 0.1138 - val_loss: 4.3456 - val_accuracy: 0.1095
# Epoch 32/80
# 791/791 [==============================] - 7s 8ms/step - loss: 4.8326 - accuracy: 0.1152 - val_loss: 4.3501 - val_accuracy: 0.1141
# Epoch 33/80
# 791/791 [==============================] - 7s 9ms/step - loss: 4.8239 - accuracy: 0.1159 - val_loss: 4.3600 - val_accuracy: 0.1090
# Epoch 34/80
# 791/791 [==============================] - 7s 8ms/step - loss: 4.8198 - accuracy: 0.1180 - val_loss: 4.3655 - val_accuracy: 0.1044
# Epoch 35/80
# 791/791 [==============================] - 7s 9ms/step - loss: 4.8155 - accuracy: 0.1171 - val_loss: 4.3632 - val_accuracy: 0.1107
# Epoch 36/80
# 791/791 [==============================] - 6s 8ms/step - loss: 4.8224 - accuracy: 0.1184 - val_loss: 4.3575 - val_accuracy: 0.1100
# Epoch 37/80
# 791/791 [==============================] - 7s 9ms/step - loss: 4.8158 - accuracy: 0.1204 - val_loss: 4.3221 - val_accuracy: 0.1145
# Epoch 38/80
# 791/791 [==============================] - 6s 8ms/step - loss: 4.8192 - accuracy: 0.1226 - val_loss: 4.3426 - val_accuracy: 0.1152
# Epoch 39/80
# 791/791 [==============================] - 7s 9ms/step - loss: 4.7921 - accuracy: 0.1221 - val_loss: 4.3266 - val_accuracy: 0.1199
# Epoch 40/80
# 791/791 [==============================] - 6s 8ms/step - loss: 4.8180 - accuracy: 0.1227 - val_loss: 4.3505 - val_accuracy: 0.1135
# Epoch 41/80
# 791/791 [==============================] - 7s 9ms/step - loss: 4.7981 - accuracy: 0.1238 - val_loss: 4.3285 - val_accuracy: 0.1164
# Epoch 42/80
# 791/791 [==============================] - 6s 8ms/step - loss: 4.8022 - accuracy: 0.1251 - val_loss: 4.3243 - val_accuracy: 0.1169
# Epoch 43/80
# 791/791 [==============================] - 7s 9ms/step - loss: 4.7947 - accuracy: 0.1252 - val_loss: 4.3364 - val_accuracy: 0.1146
# Epoch 44/80
# 791/791 [==============================] - 7s 8ms/step - loss: 4.7928 - accuracy: 0.1262 - val_loss: 4.3195 - val_accuracy: 0.1188
# Epoch 45/80
# 791/791 [==============================] - 7s 9ms/step - loss: 4.7776 - accuracy: 0.1274 - val_loss: 4.3362 - val_accuracy: 0.1181
# Epoch 46/80
# 791/791 [==============================] - 7s 9ms/step - loss: 4.7764 - accuracy: 0.1287 - val_loss: 4.2919 - val_accuracy: 0.1221
# Epoch 47/80
# 791/791 [==============================] - 7s 9ms/step - loss: 4.7789 - accuracy: 0.1301 - val_loss: 4.3647 - val_accuracy: 0.1132
# Epoch 48/80
# 791/791 [==============================] - 6s 8ms/step - loss: 4.7993 - accuracy: 0.1290 - val_loss: 4.2989 - val_accuracy: 0.1231
# Epoch 49/80
# 791/791 [==============================] - 7s 9ms/step - loss: 4.7716 - accuracy: 0.1324 - val_loss: 4.2843 - val_accuracy: 0.1260
# Epoch 50/80
# 791/791 [==============================] - 7s 9ms/step - loss: 4.7632 - accuracy: 0.1337 - val_loss: 4.3200 - val_accuracy: 0.1203
# Epoch 51/80
# 791/791 [==============================] - 6s 8ms/step - loss: 4.7628 - accuracy: 0.1331 - val_loss: 4.3050 - val_accuracy: 0.1201
# Epoch 52/80
# 791/791 [==============================] - 7s 9ms/step - loss: 4.7633 - accuracy: 0.1351 - val_loss: 4.2872 - val_accuracy: 0.1282
# Epoch 53/80
# 791/791 [==============================] - 7s 8ms/step - loss: 4.7533 - accuracy: 0.1369 - val_loss: 4.2739 - val_accuracy: 0.1290
# Epoch 54/80
# 791/791 [==============================] - 7s 9ms/step - loss: 4.7427 - accuracy: 0.1374 - val_loss: 4.2920 - val_accuracy: 0.1306
# Epoch 55/80
# 791/791 [==============================] - 6s 8ms/step - loss: 4.7543 - accuracy: 0.1373 - val_loss: 4.2760 - val_accuracy: 0.1247
# Epoch 56/80
# 791/791 [==============================] - 7s 9ms/step - loss: 4.7605 - accuracy: 0.1378 - val_loss: 4.2928 - val_accuracy: 0.1327
# Epoch 57/80
# 791/791 [==============================] - 6s 8ms/step - loss: 4.7518 - accuracy: 0.1385 - val_loss: 4.2899 - val_accuracy: 0.1292
# Epoch 58/80
# 791/791 [==============================] - 8s 10ms/step - loss: 4.7439 - accuracy: 0.1390 - val_loss: 4.2659 - val_accuracy: 0.1325
# Epoch 59/80
# 791/791 [==============================] - 6s 8ms/step - loss: 4.7420 - accuracy: 0.1395 - val_loss: 4.2631 - val_accuracy: 0.1385
# Epoch 60/80
# 791/791 [==============================] - 7s 9ms/step - loss: 4.7371 - accuracy: 0.1415 - val_loss: 4.3039 - val_accuracy: 0.1251
# Epoch 61/80
# 791/791 [==============================] - 7s 9ms/step - loss: 4.7353 - accuracy: 0.1406 - val_loss: 4.2951 - val_accuracy: 0.1288
# Epoch 62/80
# 791/791 [==============================] - 7s 9ms/step - loss: 4.7256 - accuracy: 0.1420 - val_loss: 4.2579 - val_accuracy: 0.1370
# Epoch 63/80
# 791/791 [==============================] - 7s 9ms/step - loss: 4.7237 - accuracy: 0.1422 - val_loss: 4.2507 - val_accuracy: 0.1388
# Epoch 64/80
# 791/791 [==============================] - 7s 8ms/step - loss: 4.7367 - accuracy: 0.1421 - val_loss: 4.2737 - val_accuracy: 0.1309
# Epoch 65/80
# 791/791 [==============================] - 7s 9ms/step - loss: 4.7452 - accuracy: 0.1444 - val_loss: 4.2630 - val_accuracy: 0.1335
# Epoch 66/80
# 791/791 [==============================] - 6s 8ms/step - loss: 4.7259 - accuracy: 0.1443 - val_loss: 4.2511 - val_accuracy: 0.1378
# Epoch 67/80
# 791/791 [==============================] - 7s 9ms/step - loss: 4.7217 - accuracy: 0.1442 - val_loss: 4.3375 - val_accuracy: 0.1205
# Epoch 68/80
# 791/791 [==============================] - 6s 8ms/step - loss: 4.7353 - accuracy: 0.1443 - val_loss: 4.2818 - val_accuracy: 0.1378
# Epoch 69/80
# 791/791 [==============================] - 7s 9ms/step - loss: 4.7064 - accuracy: 0.1460 - val_loss: 4.2549 - val_accuracy: 0.1341
# Epoch 70/80
# 791/791 [==============================] - 6s 8ms/step - loss: 4.7181 - accuracy: 0.1455 - val_loss: 4.2727 - val_accuracy: 0.1312
# Epoch 71/80
# 791/791 [==============================] - 7s 9ms/step - loss: 4.7143 - accuracy: 0.1473 - val_loss: 4.2460 - val_accuracy: 0.1401
# Epoch 72/80
# 791/791 [==============================] - 6s 8ms/step - loss: 4.7174 - accuracy: 0.1473 - val_loss: 4.2429 - val_accuracy: 0.1398
# Epoch 73/80
# 791/791 [==============================] - 8s 10ms/step - loss: 4.7121 - accuracy: 0.1479 - val_loss: 4.2298 - val_accuracy: 0.1412
# Epoch 74/80
# 791/791 [==============================] - 6s 8ms/step - loss: 4.7038 - accuracy: 0.1483 - val_loss: 4.2479 - val_accuracy: 0.1392
# Epoch 75/80
# 791/791 [==============================] - 7s 9ms/step - loss: 4.7060 - accuracy: 0.1475 - val_loss: 4.2780 - val_accuracy: 0.1310
# Epoch 76/80
# 791/791 [==============================] - 7s 8ms/step - loss: 4.6969 - accuracy: 0.1484 - val_loss: 4.2624 - val_accuracy: 0.1411
# Epoch 77/80
# 791/791 [==============================] - 7s 9ms/step - loss: 4.7079 - accuracy: 0.1494 - val_loss: 4.2378 - val_accuracy: 0.1430
# Epoch 78/80
# 791/791 [==============================] - 7s 9ms/step - loss: 4.7048 - accuracy: 0.1499 - val_loss: 4.2578 - val_accuracy: 0.1366
# Epoch 79/80
# 791/791 [==============================] - 7s 8ms/step - loss: 4.6970 - accuracy: 0.1503 - val_loss: 4.2573 - val_accuracy: 0.1404
# Epoch 80/80
# 791/791 [==============================] - 7s 9ms/step - loss: 4.7080 - accuracy: 0.1500 - val_loss: 4.2564 - val_accuracy: 0.1411

# %%
model.load_weights('/content/drive/Shareddrives/AICUP圍棋Dataset/save_Dan_bestModel/best_model.h5')

# %% [markdown]
# # Testing
#
# **PublicUpload.csv** must be in the following form:
# ```
# DTPU0000000001,id,qr,pq,pd,ab
# DTPU0000000002,ao,ab,ha,ff,qd
# DTPU0000000003,qd,gd,fh,ed,fa
# DTPU0000000004,pr,ba,dq,hh,aj
# DTPU0000000005,ph,jh,af,df,gj
# ```
#
# - Column 1: Game ID
# - Column 2: Predicted Moves, up to 5 predictions for each game
#
# The code block below is to use **dan_test_public.csv** to predict and save the results in required form. It generates the best 5 predictions for each sample and convert them to character coordinates.

# %%
def number_to_char(number):
    number_1, number_2 = divmod(number, 19)
    return chartonumbers[number_1] + chartonumbers[number_2]

def top_5_preds_with_chars(predictions):
    resulting_preds_numbers = [np.flip(np.argpartition(prediction, -5)[-5:]) for prediction in predictions]
    resulting_preds_chars = np.vectorize(number_to_char)(resulting_preds_numbers)
    return resulting_preds_chars

# %%
df = open('/content/drive/Shareddrives/AICUP圍棋Dataset/dan_test_public.csv').read().splitlines()
games_id = [i.split(',',2)[0] for i in df]
games = [i.split(',',2)[-1] for i in df]

x_testing = []

for game in games:
    moves_list = game.split(',')
    x_testing.append(prepare_input(moves_list))

x_testing = np.array(x_testing)
predictions = model.predict(x_testing)
prediction_chars = top_5_preds_with_chars(predictions)

# Save results to PublicUpload.csv
with open('/content/drive/Shareddrives/AICUP圍棋Dataset/PublicUpload.csv','a') as f:
    for index in range(len(prediction_chars)):
        answer_row = games_id[index] + ',' + ','.join(prediction_chars[index]) + '\n'
        f.write(answer_row)
# Out:
# 344/344 [==============================] - 1s 2ms/step

# %% [markdown]
# # End of Tutorial
#
# You are free to use more modern NN architectures, a better pre-processing, feature extraction methods to achieve much better accuracy!

# %%
print(prediction_chars)
# Out:
# [['mn' 'nm' 'ml' 'mk' 'll']
#  ['jn' 'kn' 'im' 'jo' 'km']
#  ['jf' 'he' 'gf' 'ig' 'hg']
#  ...
#  ['eq' 'fp' 'fr' 'gq' 'go']
#  ['gi' 'fg' 'hh' 'eh' 'eg']
#  ['gk' 'im' 'hj' 'jl' 'hn']]
